# %%
#Mini project 1 ~ Bank account system.

class BankAccount:
    def __init__(self,name,balance=0):
        self.name=name
        self.__balance=balance
        
    def deposit(self,amount):
        self.__balance+=amount

    def withdraw(self,amount):
        if amount>=self.__balance:
            self.__balance-=amount
        else:
            print("Insufficient balance")
    def get_balance(self):
       return self.__balance

acc = BankAccount("Trick")
acc.deposit(1000)
acc.withdraw(200)
print(acc.get_balance())
# Out:
# Insufficient balance
# 1000

# %%
# Mini project 2 ~Bank account system

#Creating the BankAccount class (1)

class BankAccount:
    def __init__(self,name,balance=0):
        self.name=name
        self.__balance=balance

#Deposit Method (2)
    def deposit(self,amount):
        if amount>0:
            self.__balance+=amount
            print(f"{amount} deposited . New balance: {self.__balance}")
        else:
            print ("Deposit must be positive")

#Withdraw method (3)

    def withdraw(self,amount):
       if amount >self.__balance:
         print("Insufficient funds.")
       elif amount <=0:
         print("Invalid amount.")
       else:
         self.__balance-=amount
         print(f"{amount}deposited. New balance: {self.__balance}")
       

#Check balance (4)

    def get_balance(self):
       return self.__balance

#Using the class (5)

if __name__=="__main__":

#Create an account object
 acc1=BankAccount ("Trick Munyi",1000)

 #Deposit money
 acc1.deposit(500)

 #withdraw money
 acc1.withdraw(200)


 #Check balance
 print(f"current Balance: {acc1.get_balance()}")
# Out:
# 500 deposited . New balance: 1500
# 200deposited. New balance: 1300
# current Balance: 1300

# %%
if __name__ == "__main__":
    acc = BankAccount("Trick", 1000)  # start with 1000

    while True:
        print("\n--- Menu ---")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Show Transactions")
        print("5. Exit")
        choice = input("Choose an option: ")

        if choice == "1":
            amt = float(input("Enter amount to deposit: "))
            acc.deposit(amt)
        elif choice == "2":
            amt = float(input("Enter amount to withdraw: "))
            acc.withdraw(amt)
        elif choice == "3":
            print(f"Current Balance: {acc.get_balance()}")
        elif choice == "4":
            acc.show_transactions()
        elif choice == "5":
            print("Thank you for using the bank system!")
            break
        else:
            print("Invalid choice. Try again.")
# Out:
# --- Menu ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Show Transactions
# 5. Exit

# %%
# SavingsAccount class
class SavingsAccount:
    def __init__(self, name, balance=0, interest_rate=0.03):
        self.name = name
        self.__balance = balance       # private balance
        self.interest_rate = interest_rate
        self.transactions = []         # store transactions

    # Deposit method
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            self.transactions.append(f"Deposit: {amount}")
            print(f"{amount} deposited. New balance: {self.__balance}")
        else:
            print("Deposit must be positive.")

    # Withdraw method
    def withdraw(self, amount):
        if amount <= 0:
            print("Invalid amount.")
        elif amount > self.__balance:
            print("Insufficient funds.")
        else:
            self.__balance -= amount
            self.transactions.append(f"Withdraw: {amount}")
            print(f"{amount} withdrawn. New balance: {self.__balance}")

    # Check balance
    def get_balance(self):
        return self.__balance

    # Show transaction history
    def show_transactions(self):
        print(f"\nTransaction History for {self.name}:")
        for t in self.transactions:
            print(t)

    # Calculate interest
    def calculate_interest(self):
        interest = self.__balance * self.interest_rate
        print(f"Interest for {self.name}: {interest}")
        return interest

# --- Main Program ---
if __name__ == "__main__":
    # Create a savings account
    acc = SavingsAccount("Trick Munyi", 1000)

    while True:
        print("\n--- Savings Account Menu ---")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Check Balance")
        print("4. Show Transactions")
        print("5. Calculate Interest")
        print("6. Exit")

        choice = input("Choose an option: ")

        if choice == "1":
            amt = float(input("Enter amount to deposit: "))
            acc.deposit(amt)
        elif choice == "2":
            amt = float(input("Enter amount to withdraw: "))
            acc.withdraw(amt)
        elif choice == "3":
            print(f"Current Balance: {acc.get_balance()}")
        elif choice == "4":
            acc.show_transactions()
        elif choice == "5":
            acc.calculate_interest()
        elif choice == "6":
            print("Thank you for using the savings account system!")
            break
        else:
            print("Invalid choice. Try again.")
# Out:
# --- Savings Account Menu ---
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Show Transactions
# 5. Calculate Interest
# 6. Exit
